# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# * Python
# * R
# * Java
# * SQL

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# * Numpy
# * Pandas
# * Scikit-learn
# * Matplotlib
# * Tensorflow

# %% [markdown]
# | Data Science Tools | Description |
# | --- | --- |
# | Jupyter Notebook | Interactive notebook environment for data science |
# | RStudio | Integrated development environment (IDE) for R programming |
# | Visual Studio Code | Lightweight code editor with data science extensions |
# | Tableau | Data visualization and business intelligence tool |
# | GitHub | Version control and collaborative coding platform |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
#This a simple arithmetic expression to mutiply then add integers.
(3*4)+5
print((3*4)+5)
# Out:
# 17

# %%
#This will convert 200 minutes to hours by diving by 60
minutes = 200
hours = minutes / 60
print(hours)
# Out:
# 3.3333333333333335

# %% [markdown]
# **Objectives:**
#
# - List popular programming languages for data science
# - Identify commonly used libraries in data science
# - Describe popular tools and technologies used in data science
# - Demonstrate how to evaluate arithmetic expressions in Python using Jupyter notebook

# %% [markdown]
# ## Author
# Zainab Saeed
